# %% [markdown]
# <a href="https://colab.research.google.com/github/harveygc2-png/INFO450/blob/main/Day3_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to APIs

# %%
import requests

# %%
response=requests.get("https://catfact.ninja/fact")

# %%
response.json()
# Out:
# {'fact': 'Both humans and cats have identical regions in the brain responsible for emotion.',
#  'length': 81}

# %%
data=response.json()
type(data)
# Out:
# dict

# %%
data['fact']
# Out:
# 'Both humans and cats have identical regions in the brain responsible for emotion.'

# %% [markdown]
# # World cup API

# %%
#This is going to pull data from world cup API
url = "https://raw.githubusercontent.com/openfootball/worldcup.json/master/2026/worldcup.json"
response=requests.get(url)

# %%
response
data=response.json()
data.keys()
data['matches']
first_match=data['matches'][0]
five_five_match=data=data['matches'][55]
five_five_match['score']['ft'][0]
# Out:
# 3

# %% [markdown]
# Using my github as an API

# %%
import requests
url = "https://raw.githubusercontent.com/harveygc2-png/INFO450/main/parts.json"
response=requests.get(url)
data=response.json()
data['parts'][1]['name']
# Out:
# 'Motherboard'

# %% [markdown]
# # Weather API

# %%
import requests

# API endpoint for historical weather
url = "https://historical-forecast-api.open-meteo.com/v1/forecast"

# Parameters for the request
params = {
"latitude": 40.7128, # Latitude for New York City
"longitude": -74.0060, # Longitude for New York City
"start_date": "2025-06-20", # Start date for the past week
"end_date": "2025-06-26", # End date for the past week
"daily": "temperature_2m_max", # Daily maximum temperature
"timezone": "auto" # Automatically adjust for timezone
}

# Fetch data from the API
response = requests.get(url, params=params)
data = response.json()

# %%
temperatures=data["daily"]['temperature_2m_max']

# %%
del(min)

# %%
min=min(temperatures)
min
# Out:
# 29.5

# %%
sum(temperatures)/len(temperatures)
# Out:
# 33.957142857142856

# %%
del min

# %%
temperatures = data["daily"]["temperature_2m_max"]

data

mean_temp = sum(temperatures) / len(temperatures)  # mean
max_temp = max(temperatures)  # max
min_temp = min(temperatures)
range_temp = max(temperatures) - min(temperatures)

temp_dict = {
    "mean": mean_temp,
    "max": max_temp,
    "min": min_temp,
    "range": range_temp
}

temp_dict
# Out:
# {'mean': 33.957142857142856,
#  'max': 39.1,
#  'min': 29.5,
#  'range': 9.600000000000001}
